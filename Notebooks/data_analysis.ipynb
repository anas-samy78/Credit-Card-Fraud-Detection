# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt 
import seaborn as sns

# %%
df = pd.read_csv("new_dtat_fraud_detection_analysis.csv")

# %%
df.shape
# Out:
# (1296675, 35)

# %%
df.columns
# Out:
# Index(['trans_date_trans_time', 'cc_num', 'merchant', 'category', 'amt',
#        'first', 'last', 'gender', 'street', 'city', 'state', 'zip', 'lat',
#        'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time', 'merch_lat',
#        'merch_long', 'is_fraud', 'trans_hour', 'trans_weekday',
#        'trans_day_name', 'trans_month', 'trans_month_name', 'trans_year',
#        'customer_age', 'city_pop_bucket', 'distance_customer_merchant',
#        'customer_avg_amt_so_far', 'max_distance_last_txn',
#        'amt_deviation_from_avg', 'customer_txn_count_1h'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296675 entries, 0 to 1296674
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   trans_date_trans_time       1296675 non-null  object
#  1   cc_num                      1296675 non-null  int64
#  2   merchant                    1296675 non-null  object
#  3   category                    1296675 non-null  object
#  4   amt                         1296675 non-null  float64
#  5   first                       1296675 non-null  object
#  6   last                        1296675 non-null  object
#  7   gender                      1296675 non-null  object
#  8   street                      1296675 non-null  object
#  9   city                        1296675 non-null  object
#  10  state                       1296675 non-null  object
#  11  zip                         1296675 non-null  int64
# ...

# %%
df.describe()
# Out:
#              cc_num           amt           zip           lat          long  \
# count  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06
# mean   4.171920e+17  7.035104e+01  4.880067e+04  3.853762e+01 -9.022634e+01
# std    1.308806e+18  1.603160e+02  2.689322e+04  5.075808e+00  1.375908e+01
# min    6.041621e+10  1.000000e+00  1.257000e+03  2.002710e+01 -1.656723e+02
# 25%    1.800429e+14  9.650000e+00  2.623700e+04  3.462050e+01 -9.679800e+01
# 50%    3.521417e+15  4.752000e+01  4.817400e+04  3.935430e+01 -8.747690e+01
# 75%    4.642255e+15  8.314000e+01  7.204200e+04  4.194040e+01 -8.015800e+01
# max    4.992346e+18  2.894890e+04  9.978300e+04  6.669330e+01 -6.795030e+01
#
#            city_pop     unix_time     merch_lat    merch_long      is_fraud  \
# count  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06
# mean   8.882444e+04  1.349244e+09  3.853734e+01 -9.022646e+01  5.788652e-03
# ...

# %%
df.groupby("trans_hour")["is_fraud"].sum().sort_values(ascending=False)
# Out:
# trans_hour
# 22    1931
# 23    1904
# 1      658
# 0      635
# 2      625
# 3      609
# 14      86
# 19      81
# 18      81
# 13      80
# 15      79
# 17      78
# 16      76
# 21      74
# 12      67
# 20      62
# 5       60
# 7       56
# 8       49
# 9       47
# 4       46
# 11      42
# 6       40
# 10      40
# Name: is_fraud, dtype: int64

# %%
df.groupby("category")["is_fraud"].sum().sort_values(ascending=False)
# Out:
# category
# grocery_pos       1743
# shopping_net      1713
# misc_net           915
# shopping_pos       843
# gas_transport      618
# misc_pos           250
# kids_pets          239
# entertainment      233
# personal_care      220
# home               198
# food_dining        151
# grocery_net        134
# health_fitness     133
# travel             116
# Name: is_fraud, dtype: int64

# %%
df.groupby("is_fraud")["amt"].mean()
# Out:
# is_fraud
# 0     67.667110
# 1    531.320092
# Name: amt, dtype: float64

# %%
df["is_fraud"].value_counts().sort_values(ascending=False)
# Out:
# is_fraud
# 0    1289169
# 1       7506
# Name: count, dtype: int64

# %%
df["is_fraud"].value_counts().sort_values(ascending=False).plot(kind="pie")
plt.grid(True, alpha=0.3)
plt.show()

# %%
df[["distance_customer_merchant","is_fraud"]].corr()
# Out:
#                             distance_customer_merchant  is_fraud
# distance_customer_merchant                    1.000000  0.000403
# is_fraud                                      0.000403  1.000000

# %%
df.groupby("trans_hour")["is_fraud"].sum().sort_values(ascending=False).plot(kind="bar",figsize=(11,5))
plt.grid(True, alpha=0.3)
plt.show()

# %%
df.groupby("category")["is_fraud"].sum().sort_values(ascending=False).plot(kind="bar",figsize=(11,5))
plt.grid(True, alpha=0.3)
plt.show()

# %%
df.groupby("is_fraud")["amt"].mean().plot(kind="bar",figsize=(6,5))
plt.grid(True, alpha=0.3)
plt.show()

# %%
df.columns
# Out:
# Index(['trans_date_trans_time', 'cc_num', 'merchant', 'category', 'amt',
#        'first', 'last', 'gender', 'street', 'city', 'state', 'zip', 'lat',
#        'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time', 'merch_lat',
#        'merch_long', 'is_fraud', 'trans_hour', 'trans_weekday',
#        'trans_day_name', 'trans_month', 'trans_month_name', 'trans_year',
#        'customer_age', 'city_pop_bucket', 'distance_customer_merchant',
#        'customer_avg_amt_so_far', 'max_distance_last_txn',
#        'amt_deviation_from_avg', 'customer_txn_count_1h'],
#       dtype='object')

# %%
df.groupby("trans_day_name")["is_fraud"].sum().sort_values(ascending=False).plot(
    kind="pie", 
    figsize=(6, 5), 
    autopct='%1.1f%%', 
    startangle=90      
)

plt.ylabel('') 
plt.show()

# %%
df.groupby("trans_month_name")["is_fraud"].sum().sort_values(ascending=False).plot(kind="bar",figsize=(12,5))
plt.grid(True, alpha=0.3)
plt.show()

# %%
df.groupby("state")["is_fraud"].sum().sort_values(ascending=False)
# Out:
# state
# NY    555
# TX    479
# PA    458
# CA    326
# OH    321
# FL    281
# IL    248
# MI    238
# AL    215
# MN    207
# VA    198
# SC    193
# MO    191
# NE    180
# WI    163
# AR    161
# MD    157
# KS    156
# KY    155
# NC    149
# OR    149
# WV    146
# GA    146
# OK    143
# IA    142
# IN    142
# TN    140
# ME    119
# NJ    118
# MS    115
# CO    113
# WY    110
# WA     96
# LA     91
# NM     82
# SD     74
# VT     72
# MA     69
# UT     61
# NH     59
# ND     57
# NV     47
# AZ     37
# AK     36
# MT     32
# DC     21
# CT     16
# RI     15
# ID     11
# DE      9
# HI      7
# Name: is_fraud, dtype: int64

# %%
df.groupby("city")["is_fraud"].sum().sort_values(ascending=False)
# Out:
# city
# Houston       39
# Warren        33
# Naples        29
# Huntsville    29
# Topeka        27
#               ..
# Coyle          0
# Woodville      0
# Wheaton        0
# Adams          0
# Zavalla        0
# Name: is_fraud, Length: 894, dtype: int64

# %%
df["gender"].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df["category"].unique()
# Out:
# array(['misc_net', 'gas_transport', 'kids_pets', 'home', 'shopping_net',
#        'food_dining', 'personal_care', 'grocery_pos', 'entertainment',
#        'shopping_pos', 'misc_pos', 'travel', 'health_fitness',
#        'grocery_net'], dtype=object)
